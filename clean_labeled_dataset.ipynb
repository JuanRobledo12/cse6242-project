# %% [markdown]
# # Refining the Main Labeled Dataset for Primary Artist Focus
# **Author:** Juan Antonio Robledo ([GitHub](https://github.com/JuanRobledo12))
#
# ### Description
# This notebook is dedicated to refining the main labeled dataset produced by our classification model. It performs specific data type conversions and eliminates instances of multiple artists within the `artists_name` attribute and other related features. The goal is to distill the dataset to only include data pertaining to the primary artist. Simplifying the dataset in this manner facilitates its use in the development of playlist generation software, ensuring a more streamlined dataset for machine learning applications.
#
# ### Execution Instructions
# - Execute the notebook in its entirety to generate a file named `cleaned_labeled_main_dataset.csv`.
# - Additionally, the final cell of the notebook creates a subset of the data intended for testing purposes. While this subset is already available in the corresponding GitHub repository, you have the option to modify this subset as needed.

# %%
import pandas as pd
import json

# %% [markdown]
# ## 1. Check the labeled dataset

# %%
df = pd.read_csv('DATA/labeled_main_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277938 entries, 0 to 277937
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   track_uri             277938 non-null  object
#  1   name                  277923 non-null  object
#  2   artists_names         277938 non-null  object
#  3   popularity            277938 non-null  int64
#  4   album_type            277938 non-null  object
#  5   is_playable           277938 non-null  bool
#  6   release_date          277938 non-null  object
#  7   artists_uris          277938 non-null  object
#  8   playlist_uris         277938 non-null  object
#  9   danceability          277938 non-null  float64
#  10  energy                277938 non-null  float64
#  11  key                   277938 non-null  float64
#  12  loudness              277938 non-null  float64
#  13  mode                  277938 non-null  float64
#  14  speechiness           277938 non-null  float64
#  15  acousticness          277938 non-null  float64
#  16  instrumentalness      277938 non-null  float64
#  17  liveness              277938 non-null  float64
#  18  valence               277938 non-null  float64
#  19  tempo                 277938 non-null  float64
#  20  analysis_url          277938 non-null  object
#  21  duration_ms           277938 non-null  float64
#  22  time_signature        277938 non-null  float64
#  23  artists_popularities  277938 non-null  object
#  24  artists_genres        277938 non-null  object
#  25  artists_followers     277938 non-null  object
#  26  predicted_mood        277938 non-null  object
# dtypes: bool(1), float64(13), int64(1), object(12)
# memory usage: 55.4+ MB

# %%
df.head()
# Out:
#                               track_uri  \
# 0  spotify:track:0yLdNVWF3Srea0uzk55zFn
# 1  spotify:track:4nrPB8O7Y7wsOCJdgXkthe
# 2  spotify:track:0DWdj2oZMBFSzRsi2Cvfzf
# 3  spotify:track:6AQbmUe0Qwf5PZnt4HmTXv
# 4  spotify:track:7oDd86yk8itslrA9HRP2ki
#
#                                     name                    artists_names  \
# 0                                Flowers                  ['Miley Cyrus']
# 1  Shakira: Bzrp Music Sessions, Vol. 53          ['Bizarrap', 'Shakira']
# 2                                    TQG                      ['KAROL G']
# 3                     Boy's a liar Pt. 2  ['PinkPantheress', 'Ice Spice']
# 4                    Die For You - Remix  ['The Weeknd', 'Ariana Grande']
#
#    popularity album_type  is_playable release_date  \
# 0         100     single         True   2023-01-13
# 1          96     single         True   2023-01-11
# 2          96      album         True   2023-02-24
# 3          96     single         True   2023-02-03
# 4          95     single         True   2023-02-24
#
#                                         artists_uris  \
# 0          ['spotify:artist:5YGY8feqx7naU7z4HrwZM6']
# 1  ['spotify:artist:716NhGYqD1jl2wI1Qkgq36', 'spo...
# 2          ['spotify:artist:790FomKkXshlbRYZFtlgla']
# 3  ['spotify:artist:78rUTD7y6Cy67W1RVzYs7t', 'spo...
# 4  ['spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ', 'spo...
#
#                                        playlist_uris  danceability  ...  \
# 0  ['spotify:playlist:3n3PnS8EAZwzCbL7AyU7Op', 's...         0.707  ...
# 1  ['spotify:playlist:6GIsLGY639AcJmgSfhQx7C', 's...         0.778  ...
# 2  ['spotify:playlist:37i9dQZF1DWUArRC04H8rI', 's...         0.720  ...
# 3  ['spotify:playlist:40L0ZzcH54squhYMUb5E3a', 's...         0.696  ...
# 4  ['spotify:playlist:5Q6nyYneiOVjbFhzz1TzVt', 's...         0.531  ...
#
#    liveness  valence    tempo  \
# 0    0.0322    0.646  117.999
# 1    0.0915    0.498  122.104
# 2    0.0936    0.607  179.974
# 3    0.2480    0.857  132.962
# 4    0.4410    0.502   66.900
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0yLd...     200455.0
# 1  https://api.spotify.com/v1/audio-analysis/4nrP...     218289.0
# 2  https://api.spotify.com/v1/audio-analysis/0DWd...     199440.0
# 3  https://api.spotify.com/v1/audio-analysis/6AQb...     131013.0
# 4  https://api.spotify.com/v1/audio-analysis/7oDd...     232857.0
#
#    time_signature  artists_popularities  \
# 0             4.0                  [92]
# 1             4.0              [88, 92]
# 2             4.0                  [93]
# 3             4.0              [84, 84]
# 4             4.0              [98, 91]
#
#                                       artists_genres     artists_followers  \
# 0                                          [['pop']]            [20250106]
# 1  [['argentine hip hop', 'pop venezolano', 'trap...  [10050089, 28191070]
# 2  [['reggaeton', 'reggaeton colombiano', 'urbano...            [33856064]
# 3                                           [[], []]     [1928246, 969451]
# 4  [['canadian contemporary r&b', 'canadian pop',...  [62165751, 89209352]
#
#    predicted_mood
# 0       energetic
# 1           happy
# 2            calm
# 3           happy
# 4            calm
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 2. Clean the dataset
#
# TODO:
#
# * ~~Drop the track_uri, album_type, is_playable, artists_uris, playlist_uris, analysis_url columns.~~
# * ~~Modify the artists_names column so it only has the first artist and it is not a list. Same for artist_popularities, artists_genres, and artist_followers, just keep the first artist data and make sure it is not a list.~~
# * ~~Make duration_ms and time_signature int64 instead of float.~~
# * Make track_uri into links to access the song

# %%
df_cleaned = df.drop(columns=['album_type', 'is_playable', 'artists_uris', 'playlist_uris', 'analysis_url'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277938 entries, 0 to 277937
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   track_uri             277938 non-null  object
#  1   name                  277923 non-null  object
#  2   artists_names         277938 non-null  object
#  3   popularity            277938 non-null  int64
#  4   release_date          277938 non-null  object
#  5   danceability          277938 non-null  float64
#  6   energy                277938 non-null  float64
#  7   key                   277938 non-null  float64
#  8   loudness              277938 non-null  float64
#  9   mode                  277938 non-null  float64
#  10  speechiness           277938 non-null  float64
#  11  acousticness          277938 non-null  float64
#  12  instrumentalness      277938 non-null  float64
#  13  liveness              277938 non-null  float64
#  14  valence               277938 non-null  float64
#  15  tempo                 277938 non-null  float64
#  16  duration_ms           277938 non-null  float64
#  17  time_signature        277938 non-null  float64
#  18  artists_popularities  277938 non-null  object
#  19  artists_genres        277938 non-null  object
#  20  artists_followers     277938 non-null  object
#  21  predicted_mood        277938 non-null  object
# dtypes: float64(13), int64(1), object(8)
# memory usage: 46.7+ MB

# %%
# Extracting the first artist's name, popularity, genre, and followers
# Assumes there's at least one artist in each list
df_cleaned['artists_names'] = df_cleaned['artists_names'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned['artists_popularities'] = df_cleaned['artists_popularities'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned['artists_genres'] = df_cleaned['artists_genres'].apply(lambda x: eval(x)[0][0] if x and eval(x)[0] else None)
df_cleaned['artists_followers'] = df_cleaned['artists_followers'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned[['artists_names', 'artists_popularities', 'artists_genres', 'artists_followers']].head()
# Out:
#     artists_names  artists_popularities             artists_genres  \
# 0     Miley Cyrus                    92                        pop
# 1        Bizarrap                    88          argentine hip hop
# 2         KAROL G                    93                  reggaeton
# 3  PinkPantheress                    84                       None
# 4      The Weeknd                    98  canadian contemporary r&b
#
#    artists_followers
# 0           20250106
# 1           10050089
# 2           33856064
# 3            1928246
# 4           62165751

# %%
df_cleaned['duration_ms'] = df_cleaned['duration_ms'].astype('int64')
df_cleaned['time_signature'] = df_cleaned['time_signature'].astype('int64')

df_cleaned.rename(columns={'popularity': 'song_popularity'}, inplace=True)

# %%
df_cleaned['track_uri'].head()
# Out:
# 0    spotify:track:0yLdNVWF3Srea0uzk55zFn
# 1    spotify:track:4nrPB8O7Y7wsOCJdgXkthe
# 2    spotify:track:0DWdj2oZMBFSzRsi2Cvfzf
# 3    spotify:track:6AQbmUe0Qwf5PZnt4HmTXv
# 4    spotify:track:7oDd86yk8itslrA9HRP2ki
# Name: track_uri, dtype: object

# %%
# Function to convert track URI to link
def convert_to_link(uri):
    song_id = uri.split(':')[-1]
    return f"open.spotify.com/track/{song_id}"

# Apply the function to the 'track_uri' column
df_cleaned['track_uri'] = df_cleaned['track_uri'].apply(convert_to_link)
df_cleaned['track_uri'].head()
# Out:
# 0    open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn
# 1    open.spotify.com/track/4nrPB8O7Y7wsOCJdgXkthe
# 2    open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf
# 3    open.spotify.com/track/6AQbmUe0Qwf5PZnt4HmTXv
# 4    open.spotify.com/track/7oDd86yk8itslrA9HRP2ki
# Name: track_uri, dtype: object

# %%
df_cleaned.head(10)
# Out:
#                                        track_uri  \
# 0  open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn
# 1  open.spotify.com/track/4nrPB8O7Y7wsOCJdgXkthe
# 2  open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf
# 3  open.spotify.com/track/6AQbmUe0Qwf5PZnt4HmTXv
# 4  open.spotify.com/track/7oDd86yk8itslrA9HRP2ki
# 5  open.spotify.com/track/0WtM2NBVQNNJLh6scP13H8
# 6  open.spotify.com/track/4uUG5RXrOk84mYEfFvj3cK
# 7  open.spotify.com/track/78Sw5GDo6AlGwTwanjXbGh
# 8  open.spotify.com/track/0V3wPSX9ygBnCm8psDIegu
# 9  open.spotify.com/track/5ww2BF9slyYgNOk37BlC4u
#
#                                     name   artists_names  song_popularity  \
# 0                                Flowers     Miley Cyrus              100
# 1  Shakira: Bzrp Music Sessions, Vol. 53        Bizarrap               96
# 2                                    TQG         KAROL G               96
# 3                     Boy's a liar Pt. 2  PinkPantheress               96
# 4                    Die For You - Remix      The Weeknd               95
# 5          Calm Down (with Selena Gomez)            Rema               94
# 6                        I'm Good (Blue)    David Guetta               94
# 7                           Here With Me            d4vd               93
# 8                              Anti-Hero    Taylor Swift               93
# 9                             La Bachata   Manuel Turizo               93
#
#   release_date  danceability  energy   key  loudness  mode  ...  \
# 0   2023-01-13         0.707   0.681   0.0    -4.325   1.0  ...
# 1   2023-01-11         0.778   0.632   2.0    -5.600   0.0  ...
# 2   2023-02-24         0.720   0.630   4.0    -3.547   0.0  ...
# 3   2023-02-03         0.696   0.809   5.0    -8.254   1.0  ...
# 4   2023-02-24         0.531   0.525   1.0    -6.500   0.0  ...
# 5   2022-08-25         0.801   0.806  11.0    -5.206   1.0  ...
# 6   2022-08-26         0.561   0.965   7.0    -3.673   0.0  ...
# 7   2022-09-22         0.574   0.469   4.0    -8.209   1.0  ...
# 8   2022-10-21         0.637   0.643   4.0    -6.571   1.0  ...
# 9   2022-05-26         0.835   0.679   7.0    -5.329   0.0  ...
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000005    0.0322    0.646  117.999       200455               4
# 1          0.000000    0.0915    0.498  122.104       218289               4
# 2          0.000000    0.0936    0.607  179.974       199440               4
# 3          0.000128    0.2480    0.857  132.962       131013               4
# 4          0.000000    0.4410    0.502   66.900       232857               4
# 5          0.000669    0.1140    0.802  106.999       239318               4
# 6          0.000007    0.3710    0.304  128.040       175238               4
# 7          0.000092    0.1280    0.288  132.023       242485               4
# 8          0.000002    0.1420    0.533   97.008       200690               4
# 9          0.000002    0.2180    0.850  124.980       162638               4
#
#    artists_popularities             artists_genres  artists_followers  \
# 0                    92                        pop           20250106
# 1                    88          argentine hip hop           10050089
# 2                    93                  reggaeton           33856064
# 3                    84                       None            1928246
# 4                    98  canadian contemporary r&b           62165751
# 5                    82               nigerian pop            2104953
# 6                    89                   big room           25778023
# 7                    82                bedroom pop             909208
# 8                   100                        pop           71194980
# 9                    85              colombian pop           11848110
#
#   predicted_mood
# 0      energetic
# 1          happy
# 2           calm
# 3          happy
# 4           calm
# 5          happy
# 6      energetic
# 7            sad
# 8          happy
# 9          happy
#
# [10 rows x 22 columns]

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277938 entries, 0 to 277937
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   track_uri             277938 non-null  object
#  1   name                  277923 non-null  object
#  2   artists_names         277938 non-null  object
#  3   song_popularity       277938 non-null  int64
#  4   release_date          277938 non-null  object
#  5   danceability          277938 non-null  float64
#  6   energy                277938 non-null  float64
#  7   key                   277938 non-null  float64
#  8   loudness              277938 non-null  float64
#  9   mode                  277938 non-null  float64
#  10  speechiness           277938 non-null  float64
#  11  acousticness          277938 non-null  float64
#  12  instrumentalness      277938 non-null  float64
#  13  liveness              277938 non-null  float64
#  14  valence               277938 non-null  float64
#  15  tempo                 277938 non-null  float64
#  16  duration_ms           277938 non-null  int64
#  17  time_signature        277938 non-null  int64
#  18  artists_popularities  277938 non-null  int64
#  19  artists_genres        213993 non-null  object
#  20  artists_followers     277938 non-null  int64
#  21  predicted_mood        277938 non-null  object
# dtypes: float64(11), int64(5), object(6)
# memory usage: 46.7+ MB

# %%
df_cleaned.to_csv('DATA/cleaned_labeled_main_dataset.csv', index=False)

# %%
# Uncomment and edit if you want to generate a new subset dataset

subset_df_cleaned = df_cleaned.head(5000)
subset_df_cleaned.to_csv('DATA/cleaned_labeled_subset_dataset.csv', index=False)

# %%
# Create JSON file version of the dataset

mood_groups = subset_df_cleaned.groupby('predicted_mood').apply(lambda x: x.to_dict(orient='records')).to_dict()

# Write the dictionary to a JSON file
with open('DATA/subset_mood_classified_tracks.json', 'w') as file:
    json.dump(mood_groups, file, indent=4)

print("JSON file has been created successfully.")
# Out:
# JSON file has been created successfully.

# %% [markdown]
# ## 3. Check the Dataset Quality
# See by yourself if the predicted labels match the song. In general it does a decent job but I think we need more complex labels to describe songs.

# %%
subset_df = pd.read_csv('DATA/cleaned_labeled_subset_dataset.csv')
subset_df = subset_df[['track_uri', 'name', 'artists_names', 'predicted_mood']]
subset_df.head()
# Out:
#                                        track_uri  \
# 0  open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn
# 1  open.spotify.com/track/4nrPB8O7Y7wsOCJdgXkthe
# 2  open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf
# 3  open.spotify.com/track/6AQbmUe0Qwf5PZnt4HmTXv
# 4  open.spotify.com/track/7oDd86yk8itslrA9HRP2ki
#
#                                     name   artists_names predicted_mood
# 0                                Flowers     Miley Cyrus      energetic
# 1  Shakira: Bzrp Music Sessions, Vol. 53        Bizarrap          happy
# 2                                    TQG         KAROL G           calm
# 3                     Boy's a liar Pt. 2  PinkPantheress          happy
# 4                    Die For You - Remix      The Weeknd           calm

# %%
required_moods = ['sad', 'calm', 'happy', 'energetic']

# Function to sample 5 songs from each mood
def sample_songs_by_mood(df, mood, n=5):
    # Filter the DataFrame by mood
    mood_df = df[df['predicted_mood'] == mood]
    # Randomly sample n rows
    sampled_df = mood_df.sample(n=n, random_state=42)
    return sampled_df

# Create an empty DataFrame to hold the samples
sampled_songs = pd.DataFrame()

# Sample 5 songs from each required mood
for mood in required_moods:
    sampled_songs = pd.concat([sampled_songs, sample_songs_by_mood(subset_df, mood, n=5)], ignore_index=True)

# Print the sampled songs
sampled_songs
# Out:
#                                         track_uri  \
# 0   open.spotify.com/track/7fQYRdNX6y8BpfmHvWVPm8
# 1   open.spotify.com/track/5x5JM1BSB6vollcIzDocqT
# 2   open.spotify.com/track/4frLb7nWtsz2ymBE6k2GRP
# 3   open.spotify.com/track/5enxwA8aAbwZbf5qCHORXi
# 4   open.spotify.com/track/3UoULw70kMsiVXxW0L3A33
# 5   open.spotify.com/track/3JA9Jsuxr4xgHXEawAdCp4
# 6   open.spotify.com/track/47EiUVwUp4C9fGccaPuUCS
# 7   open.spotify.com/track/1635wWSdp29PO3GxYhy991
# 8   open.spotify.com/track/0iOZM63lendWRTTeKhZBSC
# 9   open.spotify.com/track/4ZLzoOkj0MPWrTLvooIuaa
# 10  open.spotify.com/track/1jaTQ3nqY3oAAYyCTbIvnM
# 11  open.spotify.com/track/2QUlF7O0auutIII6Ntd7ZS
# 12  open.spotify.com/track/1mCsF9Tw4AkIZOjvZbZZdT
# 13  open.spotify.com/track/26w9NTiE9NGjW1ZvIOd1So
# 14  open.spotify.com/track/46ydq5g3k17iLJs3qMDvO6
# 15  open.spotify.com/track/2lLG56qpLP3UbcLuzMvkWX
# 16  open.spotify.com/track/3QSjVPObHxuAJc3E5nrjRn
# 17  open.spotify.com/track/754kgU5rWscRTfvlsuEwFp
# 18  open.spotify.com/track/0vHfVsEe6Ps0d8cZ9PGzSw
# 19  open.spotify.com/track/2yLa0QULdQr0qAIvVwN6B5
#
#                                                  name  \
# 0                                          恋人じゃなくなった日
# 1                                           The Climb
# 2                    Earned It (Fifty Shades Of Grey)
# 3   All Too Well (10 Minute Version) (Taylor's Ver...
# 4                                                 pov
# 5                               Just Can’t Get Enough
# 6                                              DÁKITI
# 7                                           Bel Mercy
# 8      Mrs. Robinson - From "The Graduate" Soundtrack
# 9                       Get You The Moon (feat. Snøw)
# 10                                       WHATS POPPIN
# 11                                               Vete
# 12                                    Break My Stride
# 13                                           BOOKER T
# 14                                      Hurts So Good
# 15                                     Stop Breathing
# 16                                            VILLAIN
# 17                                            Kiss Me
# 18                         Loco Por Perrearte - Remix
# 19                                   ...Ready For It?
#
#                artists_names predicted_mood
# 0                      Yuuri            sad
# 1                Miley Cyrus            sad
# 2                 The Weeknd            sad
# 3               Taylor Swift            sad
# 4              Ariana Grande            sad
# 5            Black Eyed Peas           calm
# 6                  Bad Bunny           calm
# 7                      Jengi           calm
# 8          Simon & Garfunkel           calm
# 9                       Kina           calm
# 10               Jack Harlow          happy
# 11            Grupo Frontera          happy
# 12            Matthew Wilder          happy
# 13                 Bad Bunny          happy
# 14                  Astrid S          happy
# 15             Playboi Carti      energetic
# 16                      K/DA      energetic
# 17  Sixpence None The Richer      energetic
# 18              De La Ghetto      energetic
# 19              Taylor Swift      energetic
