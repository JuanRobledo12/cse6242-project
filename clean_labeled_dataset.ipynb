# %% [markdown]
# # Refining the Main Labeled Dataset for Primary Artist Focus
# **Author:** Juan Antonio Robledo ([GitHub](https://github.com/JuanRobledo12))
#
# ### Description
# This notebook is dedicated to refining the main labeled dataset produced by our classification model. It performs specific data type conversions and eliminates instances of multiple artists within the `artists_name` attribute and other related features. The goal is to distill the dataset to only include data pertaining to the primary artist. Simplifying the dataset in this manner facilitates its use in the development of playlist generation software, ensuring a more streamlined dataset for machine learning applications.
#
# ### Execution Instructions
# - Execute the notebook in its entirety to generate a file named `cleaned_labeled_main_dataset.csv`.
# - Additionally, the final cell of the notebook creates a subset of the data intended for testing purposes. While this subset is already available in the corresponding GitHub repository, you have the option to modify this subset as needed.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Check the labeled dataset

# %%
df = pd.read_csv('labeled_main_dataset.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277938 entries, 0 to 277937
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   track_uri             277938 non-null  object
#  1   name                  277923 non-null  object
#  2   artists_names         277938 non-null  object
#  3   popularity            277938 non-null  int64
#  4   album_type            277938 non-null  object
#  5   is_playable           277938 non-null  bool
#  6   release_date          277938 non-null  object
#  7   artists_uris          277938 non-null  object
#  8   playlist_uris         277938 non-null  object
#  9   danceability          277938 non-null  float64
#  10  energy                277938 non-null  float64
#  11  key                   277938 non-null  float64
#  12  loudness              277938 non-null  float64
#  13  mode                  277938 non-null  float64
#  14  speechiness           277938 non-null  float64
#  15  acousticness          277938 non-null  float64
#  16  instrumentalness      277938 non-null  float64
#  17  liveness              277938 non-null  float64
#  18  valence               277938 non-null  float64
#  19  tempo                 277938 non-null  float64
#  20  analysis_url          277938 non-null  object
#  21  duration_ms           277938 non-null  float64
#  22  time_signature        277938 non-null  float64
#  23  artists_popularities  277938 non-null  object
#  24  artists_genres        277938 non-null  object
#  25  artists_followers     277938 non-null  object
#  26  predicted_mood        277938 non-null  object
# dtypes: bool(1), float64(13), int64(1), object(12)
# memory usage: 55.4+ MB

# %%
df.head()
# Out:
#                               track_uri  \
# 0  spotify:track:0yLdNVWF3Srea0uzk55zFn
# 1  spotify:track:4nrPB8O7Y7wsOCJdgXkthe
# 2  spotify:track:0DWdj2oZMBFSzRsi2Cvfzf
# 3  spotify:track:6AQbmUe0Qwf5PZnt4HmTXv
# 4  spotify:track:7oDd86yk8itslrA9HRP2ki
#
#                                     name                    artists_names  \
# 0                                Flowers                  ['Miley Cyrus']
# 1  Shakira: Bzrp Music Sessions, Vol. 53          ['Bizarrap', 'Shakira']
# 2                                    TQG                      ['KAROL G']
# 3                     Boy's a liar Pt. 2  ['PinkPantheress', 'Ice Spice']
# 4                    Die For You - Remix  ['The Weeknd', 'Ariana Grande']
#
#    popularity album_type  is_playable release_date  \
# 0         100     single         True   2023-01-13
# 1          96     single         True   2023-01-11
# 2          96      album         True   2023-02-24
# 3          96     single         True   2023-02-03
# 4          95     single         True   2023-02-24
#
#                                         artists_uris  \
# 0          ['spotify:artist:5YGY8feqx7naU7z4HrwZM6']
# 1  ['spotify:artist:716NhGYqD1jl2wI1Qkgq36', 'spo...
# 2          ['spotify:artist:790FomKkXshlbRYZFtlgla']
# 3  ['spotify:artist:78rUTD7y6Cy67W1RVzYs7t', 'spo...
# 4  ['spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ', 'spo...
#
#                                        playlist_uris  danceability  ...  \
# 0  ['spotify:playlist:3n3PnS8EAZwzCbL7AyU7Op', 's...         0.707  ...
# 1  ['spotify:playlist:6GIsLGY639AcJmgSfhQx7C', 's...         0.778  ...
# 2  ['spotify:playlist:37i9dQZF1DWUArRC04H8rI', 's...         0.720  ...
# 3  ['spotify:playlist:40L0ZzcH54squhYMUb5E3a', 's...         0.696  ...
# 4  ['spotify:playlist:5Q6nyYneiOVjbFhzz1TzVt', 's...         0.531  ...
#
#    liveness  valence    tempo  \
# 0    0.0322    0.646  117.999
# 1    0.0915    0.498  122.104
# 2    0.0936    0.607  179.974
# 3    0.2480    0.857  132.962
# 4    0.4410    0.502   66.900
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0yLd...     200455.0
# 1  https://api.spotify.com/v1/audio-analysis/4nrP...     218289.0
# 2  https://api.spotify.com/v1/audio-analysis/0DWd...     199440.0
# 3  https://api.spotify.com/v1/audio-analysis/6AQb...     131013.0
# 4  https://api.spotify.com/v1/audio-analysis/7oDd...     232857.0
#
#    time_signature  artists_popularities  \
# 0             4.0                  [92]
# 1             4.0              [88, 92]
# 2             4.0                  [93]
# 3             4.0              [84, 84]
# 4             4.0              [98, 91]
#
#                                       artists_genres     artists_followers  \
# 0                                          [['pop']]            [20250106]
# 1  [['argentine hip hop', 'pop venezolano', 'trap...  [10050089, 28191070]
# 2  [['reggaeton', 'reggaeton colombiano', 'urbano...            [33856064]
# 3                                           [[], []]     [1928246, 969451]
# 4  [['canadian contemporary r&b', 'canadian pop',...  [62165751, 89209352]
#
#    predicted_mood
# 0            calm
# 1             sad
# 2            calm
# 3           happy
# 4             sad
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 2. Clean the dataset
#
# TODO:
#
# * ~~Drop the track_uri, album_type, is_playable, artists_uris, playlist_uris, analysis_url columns.~~
# * ~~Modify the artists_names column so it only has the first artist and it is not a list. Same for artist_popularities, artists_genres, and artist_followers, just keep the first artist data and make sure it is not a list.~~
# * ~~Make duration_ms and time_signature int64 instead of float.~~

# %%
df_cleaned = df.drop(columns=['track_uri', 'album_type', 'is_playable', 'artists_uris', 'playlist_uris', 'analysis_url'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277938 entries, 0 to 277937
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   name                  277923 non-null  object
#  1   artists_names         277938 non-null  object
#  2   popularity            277938 non-null  int64
#  3   release_date          277938 non-null  object
#  4   danceability          277938 non-null  float64
#  5   energy                277938 non-null  float64
#  6   key                   277938 non-null  float64
#  7   loudness              277938 non-null  float64
#  8   mode                  277938 non-null  float64
#  9   speechiness           277938 non-null  float64
#  10  acousticness          277938 non-null  float64
#  11  instrumentalness      277938 non-null  float64
#  12  liveness              277938 non-null  float64
#  13  valence               277938 non-null  float64
#  14  tempo                 277938 non-null  float64
#  15  duration_ms           277938 non-null  float64
#  16  time_signature        277938 non-null  float64
#  17  artists_popularities  277938 non-null  object
#  18  artists_genres        277938 non-null  object
#  19  artists_followers     277938 non-null  object
#  20  predicted_mood        277938 non-null  object
# dtypes: float64(13), int64(1), object(7)
# memory usage: 44.5+ MB

# %%
# Extracting the first artist's name, popularity, genre, and followers
# Assumes there's at least one artist in each list
df_cleaned['artists_names'] = df_cleaned['artists_names'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned['artists_popularities'] = df_cleaned['artists_popularities'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned['artists_genres'] = df_cleaned['artists_genres'].apply(lambda x: eval(x)[0][0] if x and eval(x)[0] else None)
df_cleaned['artists_followers'] = df_cleaned['artists_followers'].apply(lambda x: eval(x)[0] if x else None)
df_cleaned[['artists_names', 'artists_popularities', 'artists_genres', 'artists_followers']].head()
# Out:
#     artists_names  artists_popularities             artists_genres  \
# 0     Miley Cyrus                    92                        pop
# 1        Bizarrap                    88          argentine hip hop
# 2         KAROL G                    93                  reggaeton
# 3  PinkPantheress                    84                       None
# 4      The Weeknd                    98  canadian contemporary r&b
#
#    artists_followers
# 0           20250106
# 1           10050089
# 2           33856064
# 3            1928246
# 4           62165751

# %%
df_cleaned['duration_ms'] = df_cleaned['duration_ms'].astype('int64')
df_cleaned['time_signature'] = df_cleaned['time_signature'].astype('int64')

# %%
df_cleaned.head(10)
# Out:
#                                                  name    artists_names  \
# 0                                             Flowers      Miley Cyrus
# 1               Shakira: Bzrp Music Sessions, Vol. 53         Bizarrap
# 2                                                 TQG          KAROL G
# 3                                  Boy's a liar Pt. 2   PinkPantheress
# 4                                 Die For You - Remix       The Weeknd
# 5                       Calm Down (with Selena Gomez)             Rema
# 6                                     I'm Good (Blue)     David Guetta
# 7                                        Here With Me             d4vd
# 8                                           Anti-Hero     Taylor Swift
# 9                                          La Bachata    Manuel Turizo
# 10                                          Kill Bill              SZA
# 11                          Unholy (feat. Kim Petras)        Sam Smith
# 12  Until I Found You (with Em Beihold) - Em Beiho...  Stephen Sanchez
# 13                                                OMG         NewJeans
# 14              Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap
# 15                                    I Ain't Worried      OneRepublic
# 16                                          As It Was     Harry Styles
# 17                                         Yandel 150           Yandel
# 18                                         Sure Thing           Miguel
# 19                                       Another Love        Tom Odell
# 20                                            Starboy       The Weeknd
# 21                                                PRC       Peso Pluma
# 22                                                AMG    Natanael Cano
# 23                                            Players        Coi Leray
# 24                                   I Wanna Be Yours   Arctic Monkeys
# 25                                Under The Influence      Chris Brown
# 26                                      Made You Look   Meghan Trainor
# 27                                          Rich Flex            Drake
# 28                                            Hey Mor            Ozuna
# 29                                              Ditto         NewJeans
# 30                                             Snooze              SZA
# 31                                    Blinding Lights       The Weeknd
# 32                             CHORRITO PA LAS ANIMAS             Feid
# 33                                          Escapism.             RAYE
# 34                                    Me Porto Bonito        Bad Bunny
# 35                                  Romantic Homicide             d4vd
# 36                                        Mockingbird           Eminem
# 37                                    Just Wanna Rock     Lil Uzi Vert
# 38                                            CUFF IT          Beyoncé
# 39  Superhero (Heroes & Villains) [with Future & C...     Metro Boomin
# 40                                             Efecto        Bad Bunny
# 41                                               SNAP        Rosa Linn
# 42                                      Ojitos Lindos        Bad Bunny
# 43                                      Fin de Semana     Oscar Maydon
# 44                                      Gato de Noche       Ñengo Flow
# 45                                             People         Libianca
# 46                                        Que Vuelvas       Carin Leon
# 47                                              10:35           Tiësto
# 48                                   Tití Me Preguntó        Bad Bunny
# 49                         Tormenta (feat. Bad Bunny)         Gorillaz
#
#     popularity release_date  danceability  energy   key  loudness  mode  \
# 0          100   2023-01-13         0.707   0.681   0.0    -4.325   1.0
# 1           96   2023-01-11         0.778   0.632   2.0    -5.600   0.0
# 2           96   2023-02-24         0.720   0.630   4.0    -3.547   0.0
# 3           96   2023-02-03         0.696   0.809   5.0    -8.254   1.0
# 4           95   2023-02-24         0.531   0.525   1.0    -6.500   0.0
# 5           94   2022-08-25         0.801   0.806  11.0    -5.206   1.0
# 6           94   2022-08-26         0.561   0.965   7.0    -3.673   0.0
# 7           93   2022-09-22         0.574   0.469   4.0    -8.209   1.0
# 8           93   2022-10-21         0.637   0.643   4.0    -6.571   1.0
# 9           93   2022-05-26         0.835   0.679   7.0    -5.329   0.0
# 10          92   2022-12-09         0.644   0.728   8.0    -5.750   1.0
# 11          92   2022-09-22         0.714   0.472   2.0    -7.375   1.0
# 12          92   2022-04-22         0.551   0.550  10.0    -5.339   1.0
# 13          92   2023-01-02         0.804   0.771   9.0    -4.067   0.0
# 14          92   2022-07-06         0.621   0.782   2.0    -5.548   1.0
# 15          91   2022-05-13         0.704   0.797   0.0    -5.927   1.0
# 16          91   2022-03-31         0.520   0.731   6.0    -5.338   0.0
# 17          91   2022-12-20         0.783   0.729   6.0    -3.549   0.0
# 18          91   2010-11-26         0.684   0.607  11.0    -8.127   0.0
# 19          91   2013-06-24         0.445   0.537   4.0    -8.532   0.0
# 20          91   2016-11-25         0.679   0.587   7.0    -7.015   1.0
# 21          91   2023-01-23         0.784   0.826   7.0    -6.340   0.0
# 22          91   2022-11-24         0.772   0.730  11.0    -6.657   0.0
# 23          91   2022-11-30         0.954   0.516   6.0    -5.817   1.0
# 24          91   2013-09-09         0.464   0.417   0.0    -9.345   0.0
# 25          90   2019-10-04         0.733   0.690   9.0    -5.529   0.0
# 26          90   2022-10-21         0.838   0.525  10.0    -3.562   1.0
# 27          90   2022-11-04         0.561   0.520  11.0    -9.342   0.0
# 28          90   2022-10-07         0.901   0.589   1.0    -6.713   0.0
# 29          90   2022-12-19         0.814   0.641   6.0    -5.957   0.0
# 30          90   2022-12-09         0.559   0.551   5.0    -7.231   1.0
# 31          90   2020-03-20         0.514   0.730   1.0    -5.934   1.0
# 32          90   2022-12-02         0.743   0.831   8.0    -4.042   0.0
# 33          90   2022-10-12         0.538   0.742   2.0    -5.355   1.0
# 34          90   2022-05-06         0.911   0.712   1.0    -5.105   0.0
# 35          90   2022-07-20         0.571   0.544   6.0   -10.613   1.0
# 36          90   2004-11-12         0.637   0.678   0.0    -3.798   1.0
# 37          90   2022-10-17         0.486   0.545  11.0    -7.924   1.0
# 38          89   2022-07-29         0.780   0.689   7.0    -5.668   1.0
# 39          89   2022-12-02         0.526   0.606   5.0    -5.300   0.0
# 40          89   2022-05-06         0.801   0.475   7.0    -8.797   0.0
# 41          89   2022-03-19         0.565   0.636   0.0    -8.198   1.0
# 42          89   2022-05-06         0.647   0.686   3.0    -5.745   0.0
# 43          89   2023-01-13         0.699   0.541   0.0    -4.943   1.0
# 44          89   2022-12-22         0.892   0.662   8.0    -3.894   1.0
# 45          89   2022-12-06         0.573   0.422  10.0    -7.621   0.0
# 46          89   2022-12-09         0.491   0.643  10.0    -4.309   1.0
# 47          89   2022-11-03         0.696   0.793   8.0    -5.733   1.0
# 48          89   2022-05-06         0.650   0.715   5.0    -5.198   0.0
# 49          89   2023-02-24         0.637   0.768   0.0    -6.468   1.0
#
#     speechiness  ...  instrumentalness  liveness  valence    tempo  \
# 0        0.0668  ...          0.000005    0.0322   0.6460  117.999
# 1        0.0493  ...          0.000000    0.0915   0.4980  122.104
# 2        0.2770  ...          0.000000    0.0936   0.6070  179.974
# 3        0.0500  ...          0.000128    0.2480   0.8570  132.962
# 4        0.0671  ...          0.000000    0.4410   0.5020   66.900
# 5        0.0381  ...          0.000669    0.1140   0.8020  106.999
# 6        0.0343  ...          0.000007    0.3710   0.3040  128.040
# 7        0.0254  ...          0.000092    0.1280   0.2880  132.023
# 8        0.0519  ...          0.000002    0.1420   0.5330   97.008
# 9        0.0364  ...          0.000002    0.2180   0.8500  124.980
# 10       0.0351  ...          0.169000    0.1610   0.4300   88.993
# 11       0.0864  ...          0.000005    0.2660   0.2380  131.121
# 12       0.0286  ...          0.000000    0.2020   0.3420  101.190
# 13       0.0433  ...          0.000003    0.1080   0.7390  126.956
# 14       0.0440  ...          0.033000    0.2300   0.5500  128.033
# 15       0.0475  ...          0.000745    0.0546   0.8250  139.994
# 16       0.0557  ...          0.001010    0.3110   0.6620  173.930
# 17       0.0691  ...          0.000272    0.1000   0.5800  167.968
# 18       0.1000  ...          0.000307    0.1910   0.4980   81.001
# 19       0.0400  ...          0.000017    0.0944   0.1310  122.769
# 20       0.2760  ...          0.000006    0.1370   0.4860  186.003
# 21       0.0538  ...          0.000071    0.1230   0.8930  138.078
# 22       0.0972  ...          0.000107    0.2740   0.7860  136.175
# 23       0.1600  ...          0.000008    0.0504   0.6240  105.001
# 24       0.0256  ...          0.022000    0.0974   0.4790   67.528
# 25       0.0427  ...          0.000001    0.1050   0.3100  116.992
# 26       0.0665  ...          0.000002    0.0771   0.8840  144.981
# 27       0.2440  ...          0.000002    0.3550   0.4240  153.150
# 28       0.2890  ...          0.000237    0.0992   0.3990   98.002
# 29       0.1110  ...          0.000000    0.0993   0.1830  133.854
# 30       0.1320  ...          0.000000    0.1100   0.3920  143.008
# 31       0.0598  ...          0.000095    0.0897   0.3340  171.005
# 32       0.0584  ...          0.000064    0.3500   0.6090   95.975
# 33       0.1140  ...          0.000047    0.0934   0.2500   96.107
# 34       0.0817  ...          0.000027    0.0933   0.4250   92.005
# 35       0.0299  ...          0.008050    0.3220   0.2160  132.052
# 36       0.2660  ...          0.000000    0.1560   0.2540   84.039
# 37       0.0336  ...          0.004740    0.0642   0.0385  150.187
# 38       0.1410  ...          0.000010    0.0698   0.6420  115.042
# 39       0.2590  ...          0.000002    0.1940   0.4920  116.622
# 40       0.0516  ...          0.000017    0.0639   0.2340   98.047
# 41       0.0638  ...          0.000010    0.4470   0.5250  170.010
# 42       0.0413  ...          0.000001    0.5280   0.2680   79.928
# 43       0.0826  ...          0.000000    0.0916   0.3650   98.395
# 44       0.1620  ...          0.000001    0.3630   0.6070   93.976
# 45       0.0678  ...          0.000013    0.1020   0.6930  124.357
# 46       0.0442  ...          0.000000    0.1090   0.7790  162.469
# 47       0.0970  ...          0.000004    0.1800   0.6980  120.003
# 48       0.2530  ...          0.000291    0.1260   0.1870  106.672
# 49       0.0560  ...          0.001920    0.3780   0.2970   94.982
#
#     duration_ms  time_signature  artists_popularities  \
# 0        200455               4                    92
# 1        218289               4                    88
# 2        199440               4                    93
# 3        131013               4                    84
# 4        232857               4                    98
# 5        239318               4                    82
# 6        175238               4                    89
# 7        242485               4                    82
# 8        200690               4                   100
# 9        162638               4                    85
# 10       153947               4                    93
# 11       156943               4                    88
# 12       176440               3                    81
# 13       212253               4                    84
# 14       198938               4                    88
# 15       148486               4                    85
# 16       167303               4                    90
# 17       216148               4                    83
# 18       195373               4                    83
# 19       244360               4                    79
# 20       230453               4                    98
# 21       184066               3                    91
# 22       174943               3                    87
# 23       139560               4                    78
# 24       183956               4                    88
# 25       184613               4                    89
# 26       134256               4                    82
# 27       239360               3                    97
# 28       196600               4                    89
# 29       185507               4                    84
# 30       201800               4                    93
# 31       200040               4                    98
# 32       168133               4                    93
# 33       272373               4                    81
# 34       178567               4                    98
# 35       132631               4                    82
# 36       250760               4                    92
# 37       123891               4                    88
# 38       225389               4                    87
# 39       182667               4                    90
# 40       213061               4                    98
# 41       179551               4                    75
# 42       258299               4                    98
# 43       224921               4                    78
# 44       227013               4                    83
# 45       184791               5                    75
# 46       169419               4                    85
# 47       172253               4                    86
# 48       243717               4                    98
# 49       193464               4                    84
#
#                 artists_genres artists_followers  predicted_mood
# 0                          pop          20250106            calm
# 1            argentine hip hop          10050089             sad
# 2                    reggaeton          33856064            calm
# 3                         None           1928246           happy
# 4    canadian contemporary r&b          62165751             sad
# 5                 nigerian pop           2104953       energetic
# 6                     big room          25778023       energetic
# 7                  bedroom pop            909208             sad
# 8                          pop          71194980             sad
# 9                colombian pop          11848110            calm
# 10                         pop          11705818             sad
# 11                         pop          22222730             sad
# 12     gen z singer-songwriter            552521             sad
# 13                       k-pop           2902877           happy
# 14           argentine hip hop          10050089       energetic
# 15                  piano rock          15330100           happy
# 16                         pop          26880130           happy
# 17               latin hip hop           6769778            calm
# 18                   dance pop           4564827       energetic
# 19                   chill pop           3011274             sad
# 20   canadian contemporary r&b          62165751            calm
# 21                sad sierreno           1548818       energetic
# 22                     corrido           6173797       energetic
# 23  new jersey underground rap            527561            calm
# 24                 garage rock          19236004             sad
# 25                   dance pop          19062148             sad
# 26                   dance pop          13146302            calm
# 27            canadian hip hop          73660940            calm
# 28            puerto rican pop          36210630            calm
# 29                       k-pop           2902877            calm
# 30                         pop          11705818            calm
# 31   canadian contemporary r&b          62165751             sad
# 32               colombian pop           4443557       energetic
# 33                   dance pop            818449       energetic
# 34                   reggaeton          67091189             sad
# 35                 bedroom pop            909208             sad
# 36             detroit hip hop          68427443            calm
# 37                 melodic rap          14848663             sad
# 38                   dance pop          34130158            calm
# 39                         rap           3983089            calm
# 40                   reggaeton          67091189             sad
# 41                       alt z            239302             sad
# 42                   reggaeton          67091189             sad
# 43                     corrido            306750             sad
# 44               latin hip hop           4351004            calm
# 45                        None            130844             sad
# 46                     corrido           5934383             sad
# 47                    big room           6816046       energetic
# 48                   reggaeton          67091189            calm
# 49         alternative hip hop          10267756       energetic
#
# [50 rows x 21 columns]

# %%
df_cleaned.to_csv('cleaned_labeled_main_dataset.csv', index=False)

# %%
# Uncomment and edit if you want to generate a new subset dataset


# subset_df_cleaned = df_cleaned.head(2000)
# subset_df_cleaned.to_csv('cleaned_labeled_subset_dataset.csv', index=False)
